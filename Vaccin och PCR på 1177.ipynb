# %% [markdown]
# # VGR:s "Visa tider" för vaccination
# Letar upp alla listade kommuner, kollar alla listade mottagningar. De mottagningar som enbart länkar till 1177.se ska ha en "gul ruta" för att klara detta test.

# %% [markdown]
# ## 1. Vilka har en gul ruta, nämner PCR eller vaccin?

# %%
from bs4 import BeautifulSoup
import requests

print(f"har_gul_ruta;namner_PCR;namner_vaccin;vc_namn;vc_url")

kontaktkort = ['https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Achima-Care-Uddevalla-vardcentral-Uddevalla/', 'https://www.ptj.se/alepraktiken/', 'https://www.ptj.se/allekliniken-sleipner/start/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Allemanshalsans-vardcentral-City-Skovde/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Allemanshalsan-vardcentral-Lunden-Skovde/', 'https://www.backaplanvc.se/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Boras-Vardcentral/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Bramhults-Vardcentral-Bramhult-Boras/', 'https://capio.se/tips-och-rad/coronaviruset/vaccination-mot-covid-19/boka-tid-i-vgr/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Capio-Lakarhus-Angered-Angered/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Capio-Lakarhus-Hjortmossen-Trollhattan/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Capio-Lakarhus-Kvillebacken-Hisingen/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Capio-Lakarhus-Lysekil-Lysekil/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Capio-Lakarhus-Stenungsund-Stenungsund/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Capio-Vardcentral-Lundby-Lundby/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Citylakarna-boras-Boras/', 'https://www.distriktslakarna.se/', 'https://www.distriktslakarna.se/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Doktor-se-Adina-Halsans-vardcentral-Nol-Nol/', 'https://notkarnandrivein.se/', 'https://www.familjelakarnamolnlycke.se/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Herkules-Vardcentral-Boras/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/HalsoBrunnen-vardcentral-Ulricehamn/', 'https://www.hchjo.se/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Hono-Vardcentral-Hono/', 'https://www.ptj.se/johannesvarden/start/covid-19/#Vaccination', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Kvarterskliniken-Tanum-Tanumshede/', 'https://www.lextorpvc.se/', 'https://www.ptj.se/maria-alberts-vardcentral/start/', 'https://www.medipart.se/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Medpro-Clinic-Bralanda-Torpa-Vardcentral/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Medpro-Clinic-Lilla-Edet-Vardcentral/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Medpro-Clinic-Noltorp-Vardcentral/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Medpro-Clinic-Stavre-Vardcentral/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Medpro-Clinic-Amal-Vardcentral/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Bengtsfors-vardcentral-Bengtsfors/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Billingen-vardcentral-Skovde/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Boda-vardcentral-Boras/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Bollebygd-vardcentral-Bollebygd/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Backefors-vardcentral-Backefors/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Dagson-vardcentral-Uddevalla/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Dalaberg-vardcentral-Uddevalla/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Dals-Ed-vardcentral-Ed/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Dalsjofors-vardcentral-Dalsjofors/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Fjallbacka-vardcentral-Fjallbacka/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Floda-vardcentral-Floda/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Fristad-vardcentral-Boras/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Furulund-vardcentral-Partille/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Fargelanda-vardcentral-Fargelanda/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Grabo-vardcentral-Grabo/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Guldvingen-vardcentral-Lidkoping/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Gullspang-vardcentral-Gullspang/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Heimdal-vardcentral-Boras/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Hentorp-vardcentral-Skovde/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Herrestad-vardcentral-Uddevalla/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Karlsborg-vardcentral-Karlsborg/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Kongahalla-vardcentral-Kungalv/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Kungshamn-vardcentral-Kungshamn/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Kallstorp-vardcentral-Trollhattan/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Landvetter-vardcentral-Landvetter/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Lerum-vardcentral-Lerum/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Lindome-vardcentral-Lindome/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Ljungskile-vardcentral-Ljungskile/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Lysekil-vardcentral-Lysekil/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Mariestad-vardcentral-Mariestad/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Mellerud-vardcentral-Mellerud/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Munkedal-vardcentral-Munkedal/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Mosseberg-vardcentral-Falkoping/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Norrmalm-vardcentral-Skovde/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Nossebro-vardcentral-Nossebro/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Oden-vardcentral-Falkoping/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Partille-vardcentral-Partille/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Sandared-vardcentral-Sandared/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Sjobo-vardcentral-Boras/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Skene-vardcentral-Skene/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Skogslyckan-vardcentral-Uddevalla/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Solgarde-vardcentral-Kungalv/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Sollebrunn-vardcentral-Sollebrunn/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Stenungsund-vardcentral-Stenungsund/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Stora-Hoga-vardcentral-Stora-Hoga/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Svenljunga-vardcentral-Svenljunga/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Sylte-vardcentral-Trollhattan/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Sodra-Ryd-vardcentral-Skovde/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Sodra-torget-vardcentral-Boras/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Tanumshede-vardcentral-Tanumshede/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Tidaholm-vardcentral-Tidaholm/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Tidan-vardcentral-Tidan/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Tjorn-vardcentral-Kallekarr/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Trandared-vardcentral-Boras/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Tranemo-vardcentral-Tranemo/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Toreboda-vardcentral-Toreboda/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Vara-vardcentral-Vara/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Vargon-vardcentral-Vargon/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Vargarda-vardcentral-Vargarda/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Alvangen-vardcentral-Alvangen/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Angabo-vardcentral-Alingsas/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Ockero-vardcentral-Ockero/', 'https://friskvaderstorgetvardcentral.se/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Notkarnan-Hovas-Askim-Familjelakare-och-BVC-Askim/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Notkarnan-Kortedala-Vardcentral-och-BVC-Kortedala/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Notkarnan-Kallered-Familjelakare-och-BVC-Kallered/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Omtanken-Vardcentral-Frolunda-Torg-Vastra-Frolunda/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Omtanken-Vardcentral-Grimmered-Goteborg/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Omtanken-Vardcentral-Jarnhalsan/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Omtanken-Vardcentral-Kallered/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Omtanken-Vardcentral-Landala-Goteborg/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Omtanken-Vardcentral-Majorna-Goteborg/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Omtanken-Vardcentral-Pedagogen-Park-Molndal/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Omtanken-Vardcentral-Aby-Molndal/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Plus7-Vardcentralen-Centrum/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Primapraktiken-Trollhattan/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Ravlanda-Vardcentral/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/?st=c232a102-5b8d-45bd-baf7-8748caadb118&nearby=false&s=rel&g=&lat=&lng=&location=&caretype=&q=eh%C3%A4lsa', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Skagerns-Vard-och-Halsoenhet-Gullspang/', 'https://www.skepplandalakarhus.se/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Sotenas-Vardcentral-i-Hunnebostrand-Hunnebostrand/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Satila-Vardcentral/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Savedalens-Vardcentral-och-BVC-Partille/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Tranehalsan-Tranemo/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Ugglans-Vardcentral-Fredriksdal-Krokslatt/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Viskaforskliniken-Viskafors/', 'https://www.ptj.se/vardcentralen-centrum-skovde/boka-tid-online22/', 'https://vckusten.se/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Vardcentralen-Lakarhuset-Centrum/', 'https://www.brackediakoni.se/vilan', 'https://alvangenslakarhus.se/', 'https://halsahemma.se/', 'https://unicare-mobile.collabodoc.com/Vaccination/Information?careCenterId=2', 'https://team-hf.se/', 'https://www.heartbeathlr.se/', 'https://www.heartbeathlr.se/', 'https://www.kronansapotek.se/tjanster/vaccinering-covid19/', 'https://www.kronansapotek.se/tjanster/vaccinering-covid19/', 'https://www.kronansapotek.se/tjanster/vaccinering-covid19/', 'https://www.kronansapotek.se/tjanster/vaccinering-covid19/', 'https://www.kronansapotek.se/tjanster/vaccinering-covid19/', 'https://www.kronansapotek.se/tjanster/vaccinering-covid19/', 'https://www.kronansapotek.se/tjanster/vaccinering-covid19/', 'https://www.kronansapotek.se/tjanster/vaccinering-covid19/', 'https://www.kronansapotek.se/tjanster/vaccinering-covid19/', 'https://www.kronansapotek.se/tjanster/vaccinering-covid19/', 'https://www.kronansapotek.se/tjanster/vaccinering-covid19/', 'https://www.kronansapotek.se/tjanster/vaccinering-covid19/', 'https://www.kronansapotek.se/tjanster/vaccinering-covid19/', 'https://www.kronansapotek.se/tjanster/vaccinering-covid19/', 'https://www.kronansapotek.se/tjanster/vaccinering-covid19/', 'https://www.kronansapotek.se/tjanster/vaccinering-covid19/', 'https://www.kronansapotek.se/tjanster/vaccinering-covid19/', 'https://www.kronansapotek.se/tjanster/vaccinering-covid19/', 'https://www.kronansapotek.se/tjanster/vaccinering-covid19/', 'https://www.kronansapotek.se/tjanster/vaccinering-covid19/', 'https://www.kronansapotek.se/tjanster/vaccinering-covid19/', 'https://www.kronansapotek.se/tjanster/vaccinering-covid19/', 'https://www.kronansapotek.se/tjanster/vaccinering-covid19/', 'https://www.vaccina.se/', 'https://www.vaccina.se/', 'https://www.vaccina.se/', 'https://www.vaccina.se/', 'https://www.vaccina.se/', 'https://www.vaccina.se/', 'https://www.vaccina.se/', 'https://www.mindoktor.se/kliniken/ica-maxi-kungalv/', 'https://www.mindoktor.se/kliniken/nordstan/', 'https://www.mindoktor.se/kliniken/ica-maxi-boras/', 'https://doktorbjorn.se/', 'https://doktorbjorn.se/', 'https://doktorbjorn.se/', 'https://doktorbjorn.se/', 'https://vaccindirekt.se/', 'https://vaccindirekt.se/', 'https://vaccindirekt.se/', 'https://doktor24.se/vaccin/covid-vaccin/', 'https://doktor24.se/vaccin/covid-vaccin/', 'https://doktor24.se/vaccin/covid-vaccin/', 'https://doktor24.se/vaccin/covid-vaccin/', 'https://doktor24.se/vaccin/covid-vaccin/', 'https://doktor24.se/vaccin/covid-vaccin/', 'https://sveavaccin.se/', 'https://sveavaccin.se/', 'https://sveavaccin.se/', 'https://sveavaccin.se/', 'https://sveavaccin.se/', 'https://www.previa.se/']

ordlista_pcr = ['PCR-test', 'covid19', 'covid-19', 'SARS-CoV-2', 'antikropp', 'provtagning']
ordlista_vaccin = ['vaccin', 'astra zeneca']


def ordmarkaren_PCR(text):
    return_bool = 'nej'
    #print(type(text))
    
    for ord in ordlista_pcr:
        #print(ord.lower())

        if ord.lower() in text.lower():
            # print(ord.lower(), 'finns i sidans text')
            return_bool = 'ja'
    
    return return_bool

def ordmarkaren_vaccin(text):
    return_bool = 'nej'
    #print(type(text))
    
    for ord in ordlista_vaccin:
        #print(ord.lower())

        if ord.lower() in text.lower():
            # print(ord.lower(), 'finns i sidans text')
            return_bool = 'ja'
    
    return return_bool



for vc_kontaktkort in kontaktkort:
    vc_html = requests.get(vc_kontaktkort)
    soup = BeautifulSoup(vc_html.text, 'html.parser')
    #print(vc_kontaktkort)
    
    if '<div class="contact-alert">' in vc_html.text:
        gul_text = soup.find("div", {"class": "contact-alert"})
        print(f"ja; {ordmarkaren_PCR(gul_text.getText())}; {ordmarkaren_vaccin(gul_text.getText())}; {soup.title.text.replace(' - 1177 Vårdguiden', '')}; {vc_kontaktkort}")
    else:
        print(f"nej; nej; nej; {soup.title.text}; {vc_kontaktkort}")

# %% [markdown]
# ## 2. Leta antal lediga tider

# %%
from bs4 import BeautifulSoup
import requests

startsida_pcr = 'https://www.vgregion.se/ov/vaccinationstider/vaccinationstider/'
startsida_html = requests.get(startsida_pcr)
soup = BeautifulSoup(startsida_html.text, 'html.parser')

kommun_adresser = []

for link in soup.find_all('a'):
    if 'vgregion.se/ov/vaccinationstider/vaccinationstider/' in link.get('href'):
        kommun_adresser.append(link.get('href'))


print(f"Antal listade kommuner: {len(kommun_adresser)}")
print("Alla kommunadresser", kommun_adresser)
# Out:
# Antal listade kommuner: 49
# ...

# %% [markdown]
# ### 2.1 Lediga tider per kommun

# %%
import re

def hitta_antal_tider(kommun_text):
    """kommun_text = kommun_text.replace('Mer än ', '')
    r1 = re.findall(r"(?:\()(\d+)", kommun_text)
    tider = 0

    for mottagning_med_tider in r1:
        antal = int(mottagning_med_tider)
        tider += antal

    return tider"""
    antal = kommun_text.find_all("div", {"class": "vgr-badge vgr-badge--info"})
    
    #r1 = re.findall(r"(?:\()(\d+)", kommun_text)
    tider = 0

    for mottagning_med_tider in antal:
        if 'Inga bokningsbara tider' not in mottagning_med_tider.text:
            tider += int(mottagning_med_tider.text.replace('Mer än ', '').split(' ')[0])
            #print(tider)
            #antal = int(mottagning_med_tider)
            #tider += antal
    
    return tider

def mottagningar_med_dropin(kommun_text):
    antal = kommun_text.find_all("div", {"class": "vgr-badge vgr-badge--success"})
    
    return len(antal)


def mottagningar_med_integration(kommun_text):
    antal = kommun_text.find_all("div", {"class": "vgr-badge vgr-badge--info"})
    
    return len(antal)


def antal_mottagningar(kommun_text):
    #soup = BeautifulSoup(kommun_text.text, 'html.parser')
    antal = kommun_text.find_all("b", {"id": "mottagning-count"})
    
    #print(antal[0].text.replace('Antal mottagningar: ', ''))
    
    #for siffra in antal:
    return antal[0].text.replace('Antal mottagningar: ', '')

def write_file(file, content):
    """Writes a file at given location
    Attributes: file for location, content for the file's contents
    """
    f = open(file, 'w')
    f.write(content)

    f.close()

output = []
output.append(f"lediga_tider; antal_vaccinmottagningar; dropin_mottagningar; antal_mottagningar_med_integration; kommun_namn")

print(f"lediga_tider; antal_vaccinmottagningar; dropin_mottagningar; antal_mottagningar_med_integration; kommun_namn")

for kommun_url in kommun_adresser:
    kommun_text = requests.get(kommun_url)
    soup = BeautifulSoup(kommun_text.text, 'html.parser')
    outputline = f"{hitta_antal_tider(soup)}; {antal_mottagningar(soup)}; {mottagningar_med_dropin(soup)}; {mottagningar_med_integration(soup)}; {soup.title.text.replace(' - Västra Götalandsregionen', '').replace('Vaccination mot covid-19 ', '').replace('i ', '').replace('på ', '')}"
    print(outputline)
    
    output.append(outputline)
    
write_file('output.csv', '\n'.join(output))

#print('\n'.join(output))

# %% [markdown]
# ## 2.1.1 Vilka är inte integrerade

# %%
def mottagningar_utan_integration(kommun_text):
    antal = kommun_text.find_all("article", {"class": "vgr-listitem"})
    
    for mottagning in antal:
        #print(mottagning, '\n\n')
        
        rakna_badges = len(mottagning.find_all("div", {"class": "vgr-badge vgr-badge--info"}))
        
        if rakna_badges == 0:            
            #print(type(mottagning.h3.text))
            
            print(f"{mottagning.h3.text}; {soup.title.text.replace(' - Västra Götalandsregionen', '').replace('Vaccination mot covid-19 ', '').replace('i ', '').replace('på ', '')}")


print(f"mottagningsnamn; kommun")

for kommun_url in kommun_adresser:
    kommun_text = requests.get(kommun_url)
    soup = BeautifulSoup(kommun_text.text, 'html.parser')
    mottagningar_utan_integration(soup)
# Out:
# mottagningsnamn; kommun
# Alepraktiken; Ale
# Bohus Vårdcentral och BVC; Ale
# Skepplanda Läkarhus; Ale
# Älvängens Läkarhus; Ale
# Medpro Clinic Noltorp vårdcentral; Alingsås
# Medpro Clinic Bengtsfors; Bengtsfors
# Borås vårdcentral; Borås
# Brämhults Vårdcentral; Borås
# Cityläkarna Borås; Borås
# Svea vaccin Borås; Borås
# Medpro Clinic Dals-Ed; Dals-Ed
# Medpro Clinic Färgelanda; Färgelanda
# Capio Vårdcentral Grästorp; Grästorp
# Medpro Clinic Gullspång; Gullspång
# Medpro Clinic Hova; Gullspång
# Skagerns vård- och hälsoenhet; Gullspång
# Backa röd; Göteborg
# Backaplan Vårdcentral och BVC; Göteborg
# Capio  Vårdcentral Selma; Göteborg
# Capio Vårdcentral Amhult; Göteborg
# Capio Vårdcentral Angered; Göteborg
# Capio Vårdcentral Axess, Haga-Annedal; Göteborg
# Capio Vårdcentral Gårda; Göteborg
# Capio Vårdcentral Hovås; Göteborg
# Capio Vårdcentral Kvillebäcken; Göteborg
# Capio Vårdcentral Lundby; Göteborg
# Eriksbo/Hjällbo; Göteborg
# Familjehälsan Vårdcentral; Göteborg
# ...

# %% [markdown]
# ## 2.1.2 Kan visa tider men gör det inte
# Listning av vilka som kan visa tider men där tiderna tagit slut, vi letar i fel tidbok, de inte släppt tider så vi kan hitta dem, etc.

# %%
def integrerade_utan_tider(kommun_text):
    antal = kommun_text.find_all("article", {"class": "vgr-listitem"})
    
    for mottagning in antal:
        #print(mottagning, '\n\n')
        
        har_integration = mottagning.find("div", {"class": "vgr-badge vgr-badge--info"})
        #print(type(har_integration))
        
        if har_integration != None and "Inga bokningsbara tider" in har_integration.text:
            print(f"{mottagning.h3.text}; {soup.title.text.replace(' - Västra Götalandsregionen', '').replace('Vaccination mot covid-19 ', '').replace('i ', '').replace('på ', '')}")
        

print(f"mottagningsnamn; kommun")

for kommun_url in kommun_adresser:
    kommun_text = requests.get(kommun_url)
    soup = BeautifulSoup(kommun_text.text, 'html.parser')
    integrerade_utan_tider(soup)
# Out:
# mottagningsnamn; kommun
# Närhälsan Älvängen vårdcentral; Ale
# Bräcke Diakoni våc Centrum; Alingsås
# Närhälsan Ängabo vårdcentral; Alingsås
# Närhälsan Bengtsfors vårdcentral; Bengtsfors
# Närhälsan Bäckefors vårdcentral; Bengtsfors
# Allékliniken Sleipner Vårdcentral; Borås
# Herkules Vårdcentral; Borås
# Legehuset Borås Parkeringsplats Gjutaren; Borås
# Min Doktor Kliniken, ICA Maxi Borås; Borås
# Närhälsan Boda vårdcentral; Borås
# Närhälsan Dalsjöfors vårdcentral; Borås
# Närhälsan Fristad vårdcentral; Borås
# Närhälsan Heimdal vårdcentral; Borås
# Närhälsan Sandared vårdcentral; Borås
# Närhälsan Sjöbo vårdcentral; Borås
# Närhälsan Södra Torget vårdcentral; Borås
# Närhälsan Trandared vårdcentral; Borås
# Närhälsan Dals-Ed vårdcentral; Dals-Ed
# Närhälsan Mösseberg vårdcentral; Falköping
# Närhälsan Oden vårdcentral; Falköping
# Närhälsan Stenstorp vårdcentral; Falköping
# Närhälsan Färgelanda vårdcentral; Färgelanda
# Närhälsan Gullspång vårdcentral; Gullspång
# ...

# %% [markdown]
# ## 2.2 Hitta alla lediga tider

# %%
def leta_tider(kommun_text):
    if len(kommun_text) > 0:
        kommun_text = kommun_text.replace('Mer än ', '')
    
    r1 = re.findall(r"(?:\()(\d+)", kommun_text)
    tider = 0

    for mottagning_med_tider in r1:
        #print(mottagning_med_tider)
        antal = int(mottagning_med_tider)
        tider += antal

    return tider

def leta_i_kommun(url, kommun):
  html_text = requests.get(url)
  soup = BeautifulSoup(html_text.text, 'html.parser')
  bokningslankar = soup.find_all("li", {"class": "mottagningblock"})

  # print(len(bokningslankar), " vaccinatörer")
  #print("vaccinator; antal_lediga_tider; boknings_URL")

  for mottagning in bokningslankar:
    soup_mott = BeautifulSoup(mottagning.text, 'html.parser')
    lank = soup_mott.find_all("a", {"style": "display: inline-block;"})

    lediga_tider = leta_tider(soup_mott.text)
    
    if lediga_tider > 0:
      # print(hitta_nya_tider(soup_mott.text))
      #print(soup_mott)
      print(f"{mottagning.find('h3').text}; {kommun}; {lediga_tider}; {mottagning.find('a').get('href')}")

print("vaccinator; kommun; antal_lediga_tider; boknings_URL")

for kommun_url in kommun_adresser:
  html_text = requests.get(kommun_url)
  soup = BeautifulSoup(html_text.text, 'html.parser')
  #soup.title.text.replace(' - Västra Götalandsregionen', '')

  leta_i_kommun(kommun_url, soup.title.text.replace(' - Västra Götalandsregionen', '').replace('Vaccination mot covid-19 i ', '').replace('Vaccination mot covid-19 på ', ''))

#print(bokningslankar)
