# %% [markdown]
# # VGR:s "Visa tider" för PCR
# Letar upp alla listade kommuner, kollar alla listade mottagningar. De mottagningar som enbart länkar till 1177.se ska ha en "gul ruta" för att klara detta test.

# %% [markdown]
# ## 1. Vilka har en gul ruta, nämner PCR eller vaccin?

# %%
from bs4 import BeautifulSoup
import requests

print(f"har_gul_ruta;namner_PCR;namner_vaccin;vc_namn;vc_url")

kontaktkort = ['https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Achima-Care-Uddevalla-vardcentral-Uddevalla/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Alepraktiken-Nodinge/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Allemanshalsans-vardcentral-City-Skovde/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Allemanshalsan-vardcentral-Lunden-Skovde/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Bohus-Vardcentral-och-BVC/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Boras-jourcentral-Boras/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Bracke-Diakoni-Vardcentralen-Centralhalsan-Falkoping/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Bracke-Diakoni-Vardcentralen-Centrum-Alingsas/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Capio-Lakarhus-Almo-Myggenas/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Capio-Lakarhus-Angered-Angered/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Capio-Lakarhus-Hjortmossen-Trollhattan/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Capio-Lakarhus-Kvillebacken-Hisingen/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Capio-Lakarhus-Lysekil-Lysekil/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Capio-Lakarhus-Lodose-Lodose/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Capio-Lakarhus-Stenungsund-Stenungsund/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Capio-Vardcentral-Amhult-Torslanda/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Capio-vardcentral-Grastorp-Grastorp/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Capio-Vardcentral-Garda-Garda/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Capio-Vardcentral-Hovas-Askim/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Capio-Vardcentral-Lundby-Lundby/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Capio-Vardcentral-Molndal-Molndal/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Capio-Vardcentral-Orust-Orust/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Centrumpraktiken-Kungalv/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Citylakarna-boras-Boras/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Din-Klinik-Centrum/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Distriktslakarna-Molndal-Vardcentral-och-BVC/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Doktor-se-Adina-Halsans-vardcentral-Nol-Nol/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Familjelakarna-i-Molnlycke-Vardcentral-och-BVC-Molnlycke/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Gardsten-Vardcentral-Angered/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/BVC-Herkules-vardcentral-Boras/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Hisingen-jourcentral-Goteborg/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Hono-Vardcentral-Hono/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Kvarterskliniken-Avenyn-Centrum/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Kvarterskliniken-Tanum-Tanumshede/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Lextorp-Vardcentral-Trollhattan/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Maria-Alberts-Vardcentral-Trollhattan/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Medical-vardcentral-Bergsjon/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Medipart-Partille-Vardcentral-och-BVC/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Medpro-Clinic-Bralanda-Torpa-Vardcentral/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Medpro-Clinic-Lilla-Edet-Vardcentral/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Medpro-Clinic-Noltorp-Vardcentral/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Medpro-Clinic-Stavre-Vardcentral/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Medpro-Clinic-Amal-Vardcentral/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Nya-Vardcentralen-Kortedala-Torg-Kortedala/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Angered-vardcentral-Angered/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Backa-vardcentral-Hisings-Backa/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Bengtsfors-vardcentral-Bengtsfors/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Billingen-vardcentral-Skovde/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Biskopsgarden-vardcentral-Goteborg/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Bjurslatt-vardcentral-Hisingen-Goteborg/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Bjorkekarr-vardcentral-Bjorkekarr/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Boda-vardcentral-Boras/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Bollebygd-vardcentral-Bollebygd/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Bramaregarden-vardcentral-Goteborg/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Backefors-vardcentral-Backefors/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Dagson-vardcentral-Uddevalla/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Dalaberg-vardcentral-Uddevalla/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Dals-Ed-vardcentral-Ed/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Dalsjofors-vardcentral-Dalsjofors/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Ekmanska-vardcentral-Goteborg/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Eriksberg-vardcentral-Goteborg/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Fjallbacka-vardcentral-Fjallbacka/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Floda-vardcentral-Floda/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Fristad-vardcentral-Boras/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Frolunda-vardcentral-Vastra-Frolunda/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Furulund-vardcentral-Partille/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Fargelanda-vardcentral-Fargelanda/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Gamlestadstorget-vardcentral-Goteborg/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Gibraltargatan-vardcentral-Goteborg/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Grabo-vardcentral-Grabo/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Guldvingen-vardcentral-Lidkoping/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Gullspang-vardcentral-Gullspang/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Gotene-vardcentral-Gotene/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Heimdal-vardcentral-Boras/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Hentorp-vardcentral-Skovde/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Herrestad-vardcentral-Uddevalla/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Herrljunga-vardcentral-Herrljunga/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-Hindas-vardcentral-Hindas/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Narhalsan-
', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Omtanken-Vardcentral-Grimmered-Goteborg/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Omtanken-Vardcentral-Jarnhalsan/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Omtanken-Vardcentral-Landala-Goteborg/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Omtanken-Vardcentral-Majorna-Goteborg/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Omtanken-Vardcentral-Pedagogen-Park-Molndal/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Omtanken-Vardcentral-Aby-Molndal/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Plus7-Vardcentralen-Centrum/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Primapraktiken-Trollhattan/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Ravlanda-Vardcentral/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Skagerns-Vard-och-Halsoenhet-Gullspang/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Sotenas-Vardcentral-i-Hunnebostrand-Hunnebostrand/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Satila-Vardcentral/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Savedalens-Vardcentral-och-BVC-Partille/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Tranehalsan-Tranemo/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Ugglans-Vardcentral-Fredriksdal-Krokslatt/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Ugglans-vardcentral-Landvetter/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Viskaforskliniken-Viskafors/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Vardcentralen-Kusten-Ytterby/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Vardcentralen-Lakarhuset-Centrum/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Vardcentralen-Vilan-Skara/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Alvangens-Lakarhus/', 'https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Halsa-Hemma-Vardcentral/']

ordlista_pcr = ['PCR-test', 'covid19', 'covid-19', 'SARS-CoV-2', 'antikropp', 'provtagning']
ordlista_vaccin = ['vaccin', 'astra zeneca']


def ordmarkaren_PCR(text):
    return_bool = 'nej'
    #print(type(text))
    
    for ord in ordlista_pcr:
        #print(ord.lower())

        if ord.lower() in text.lower():
            # print(ord.lower(), 'finns i sidans text')
            return_bool = 'ja'
    
    return return_bool

def ordmarkaren_vaccin(text):
    return_bool = 'nej'
    #print(type(text))
    
    for ord in ordlista_vaccin:
        #print(ord.lower())

        if ord.lower() in text.lower():
            # print(ord.lower(), 'finns i sidans text')
            return_bool = 'ja'
    
    return return_bool



for vc_kontaktkort in kontaktkort:
    vc_html = requests.get(vc_kontaktkort)
    soup = BeautifulSoup(vc_html.text, 'html.parser')
    #print(vc_kontaktkort)
    
    if '<div class="contact-alert">' in vc_html.text:
        gul_text = soup.find("div", {"class": "contact-alert"})
        print(f"ja; {ordmarkaren_PCR(gul_text.getText())}; {ordmarkaren_vaccin(gul_text.getText())}; {soup.title.text.replace(' - 1177 Vårdguiden', '')}; {vc_kontaktkort}")
    else:
        print(f"nej; nej; nej; {soup.title.text}; {vc_kontaktkort}")
# Out:
# har_gul_ruta;namner_PCR;namner_vaccin;vc_namn;vc_url
# ja; ja; ja; Achima Care Uddevalla vårdcentral, Uddevalla; https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Achima-Care-Uddevalla-vardcentral-Uddevalla/
# ja; ja; ja; Alepraktiken, Nödinge; https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Alepraktiken-Nodinge/
# ja; ja; nej; Allemanshälsans vårdcentral - City, Skövde; https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Allemanshalsans-vardcentral-City-Skovde/
# ja; ja; nej; Allemanshälsan vårdcentral - Lunden, Skövde; https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Allemanshalsan-vardcentral-Lunden-Skovde/
# ja; ja; nej; Bohus Vårdcentral och BVC; https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Bohus-Vardcentral-och-BVC/
# ja; ja; ja; Borås jourcentral, Borås; https://www.1177.se/Vastra-Gotaland/hitta-vard/kontaktkort/Boras-jourcentral-Boras/
# ...
